# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
df = pd.read_csv("../data/processed/feature_engineered_data.csv")

# %%
engine = create_engine('mysql+mysqlconnector://root:12345@localhost:3306/food_delivery_db')

# %%
df.to_sql(
    name='food_delivery',     
    con=engine, 
    if_exists='replace', 
    index=False
)
# Out:
# 100000
